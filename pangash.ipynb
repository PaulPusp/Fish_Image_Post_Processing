# %%
from PIL import ImageFile

ImageFile.MAX_IMAGE_PIXELS = 99908000000  # Adjust limit as needed (in pixels)

import warnings
from cryptography.utils import CryptographyDeprecationWarning
with warnings.catch_warnings():
    warnings.filterwarnings('ignore', category=CryptographyDeprecationWarning)
    import paramiko

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o1"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# C:\Users\paulp\anaconda3\envs\rmvbg\lib\site-packages\PIL\Image.py:3218: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Error processing LRM_20240111_175022.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240111_175022.dng'
# Error processing LRM_20240111_175121.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240111_175121.dng'
# Error processing LRM_20240111_175124.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240111_175124.dng'
# Error processing LRM_20240111_175153.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240111_175153.dng'
# Error processing LRM_20240111_175155.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240111_175155.dng'
# Error processing LRM_20240114_175130.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175130.dng'
# Error processing LRM_20240114_175133.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175133.dng'
# Error processing LRM_20240114_175143.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175143.dng'
# Error processing LRM_20240114_175149.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175149.dng'
# Error processing LRM_20240114_175154.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175154.dng'
# Error processing LRM_20240114_175433.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175433.dng'
# Error processing LRM_20240114_175437.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175437.dng'
# Error processing LRM_20240114_175441.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175441.dng'
# Error processing LRM_20240114_175446.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175446.dng'
# Error processing LRM_20240114_175502.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o1\\LRM_20240114_175502.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o2"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o3"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240114_174956.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_174956.dng'
# Error processing LRM_20240114_174959.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_174959.dng'
# Error processing LRM_20240114_175003.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175003.dng'
# Error processing LRM_20240114_175013.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175013.dng'
# Error processing LRM_20240114_175018.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175018.dng'
# Error processing LRM_20240114_175023.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175023.dng'
# Error processing LRM_20240114_175314.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175314.dng'
# Error processing LRM_20240114_175320.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175320.dng'
# Error processing LRM_20240114_175337.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175337.dng'
# Error processing LRM_20240114_175346.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175346.dng'
# Error processing LRM_20240114_175507.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175507.dng'
# Error processing LRM_20240114_175513.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o3\\LRM_20240114_175513.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o4"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o5"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240114_175027.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175027.dng'
# Error processing LRM_20240114_175123.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175123.dng'
# Error processing LRM_20240114_175126.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175126.dng'
# Error processing LRM_20240114_175157.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175157.dng'
# Error processing LRM_20240114_175235.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175235.dng'
# Error processing LRM_20240114_175244.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175244.dng'
# Error processing LRM_20240114_175251.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175251.dng'
# Error processing LRM_20240114_175256.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175256.dng'
# Error processing LRM_20240114_175518.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o5\\LRM_20240114_175518.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o6"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o7"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\o8"
output_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240110_190455.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190455.dng'
# Error processing LRM_20240110_190506.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190506.dng'
# Error processing LRM_20240110_190512.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190512.dng'
# Error processing LRM_20240110_190522.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190522.dng'
# Error processing LRM_20240110_190540.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190540.dng'
# Error processing LRM_20240110_190602.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190602.dng'
# Error processing LRM_20240110_190618.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190618.dng'
# Error processing LRM_20240110_190631.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240110_190631.dng'
# Error processing LRM_20240111_172511.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172511.dng'
# Error processing LRM_20240111_172530.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172530.dng'
# Error processing LRM_20240111_172532.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172532.dng'
# Error processing LRM_20240111_172607.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172607.dng'
# Error processing LRM_20240111_172610.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172610.dng'
# Error processing LRM_20240111_172619.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172619.dng'
# Error processing LRM_20240111_172636.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172636.dng'
# Error processing LRM_20240111_172653.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_172653.dng'
# Error processing LRM_20240111_173008.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_173008.dng'
# Error processing LRM_20240111_173010.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_173010.dng'
# Error processing LRM_20240111_173025.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_173025.dng'
# Error processing LRM_20240111_173052.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_173052.dng'
# Error processing LRM_20240111_173111.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_173111.dng'
# Error processing LRM_20240111_173131.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_173131.dng'
# Error processing LRM_20240111_173144.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_173144.dng'
# Error processing LRM_20240111_174131.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_174131.dng'
# Error processing LRM_20240111_174135.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_174135.dng'
# Error processing LRM_20240111_174146.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_174146.dng'
# Error processing LRM_20240111_174214.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_174214.dng'
# Error processing LRM_20240111_174226.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_174226.dng'
# Error processing LRM_20240111_174952.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_174952.dng'
# Error processing LRM_20240111_174954.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_174954.dng'
# Error processing LRM_20240111_175019.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Pangash)\\o8\\LRM_20240111_175019.dng'

# %%
import os
import cv2

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the target width and height
target_width = 3000
target_height = 4000

# Loop through the list of files and resize them
for filename in files:
    try:
        # Open the image using OpenCV
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)
        
        # Check if height is greater than width
        height, width, _ = image.shape
        if height > width:
            # Do nothing if height is greater than width
            continue
        
        # Rotate the image to the right
        rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
        
        # Resize the rotated image using cubic interpolation for better quality
        resized_image = cv2.resize(rotated_image, (target_width, target_height), interpolation=cv2.INTER_CUBIC)
        
        # Save the resized image
        cv2.imwrite(image_path, resized_image)
    except Exception as e:
        print(f"Error processing {filename}: {e}")

# %%
import os
import random
import string

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Shuffle the list of files randomly
random.shuffle(files)

# Define characters to use for generating random filenames
characters = string.ascii_lowercase + string.digits

# Loop through the shuffled list of files and rename them randomly
for i, filename in enumerate(files):
    # Generate a random filename
    random_filename = ''.join(random.choices(characters, k=10)) + os.path.splitext(filename)[1]
    
    # Construct the new file path with the random filename
    new_filepath = os.path.join(input_folder, random_filename)
    
    # Rename the file
    os.rename(os.path.join(input_folder, filename), new_filepath)

# %%
import os

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(Pangash)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the prefix for renaming
prefix = "P"

# Loop through the list of files and rename them sequentially
for i, filename in enumerate(files, start=1):
    try:
        # Generate the new filename
        new_filename = f"{prefix}{i:03}.jpg"
        
        # Construct the new file path
        old_filepath = os.path.join(input_folder, filename)
        new_filepath = os.path.join(input_folder, new_filename)
        
        # Rename the file
        os.rename(old_filepath, new_filepath)
    except Exception as e:
        print(f"Error renaming {filename}: {e}")

# %%
import os
import cv2

# Define input folder
input_folder = "E:\\Work\\Base data\\cropped\\Pangash\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the target width and height
target_width = 3000
target_height = 4000

# Loop through the list of files and resize them
for filename in files:
    try:
        # Open the image using OpenCV
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)
        
        # Resize the image to the target dimensions
        resized_image = cv2.resize(image, (target_width, target_height))
        
        # Save the resized image
        cv2.imwrite(image_path, resized_image)
    except Exception as e:
        print(f"Error processing {filename}: {e}")
