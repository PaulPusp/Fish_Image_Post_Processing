# %%
from PIL import ImageFile

ImageFile.MAX_IMAGE_PIXELS = 99908000000  # Adjust limit as needed (in pixels)

import warnings
from cryptography.utils import CryptographyDeprecationWarning
with warnings.catch_warnings():
    warnings.filterwarnings('ignore', category=CryptographyDeprecationWarning)
    import paramiko

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o1"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o2"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o3"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# C:\Users\paulp\anaconda3\envs\rmvbg\lib\site-packages\PIL\Image.py:3218: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o4"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o5"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing 97.jpeg: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o5\\97.jpeg'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o6"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240102_192545.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_192545.dng'
# Error processing LRM_20240102_192556.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_192556.dng'
# Error processing LRM_20240102_192604.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_192604.dng'
# Error processing LRM_20240102_192654.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_192654.dng'
# Error processing LRM_20240102_192703.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_192703.dng'
# Error processing LRM_20240102_192714.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_192714.dng'
# Error processing LRM_20240102_195826.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_195826.dng'
# Error processing LRM_20240102_195837.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_195837.dng'
# Error processing LRM_20240102_195844.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_195844.dng'
# Error processing LRM_20240102_200508.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_200508.dng'
# Error processing LRM_20240102_200513.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_200513.dng'
# Error processing LRM_20240102_200548.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_200548.dng'
# Error processing LRM_20240102_200548.jpg: [Errno 2] No such file or directory: 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output\\LRM_20240102_200548.JPG'
# Error processing LRM_20240102_200553.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_200553.dng'
# Error processing LRM_20240102_200600.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_200600.dng'
# Error processing LRM_20240102_201218.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_201218.dng'
# Error processing LRM_20240102_201253.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_201253.dng'
# Error processing LRM_20240102_201256.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_201256.dng'
# Error processing LRM_20240102_201301.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_201301.dng'
# Error processing LRM_20240102_201324.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_201324.dng'
# Error processing LRM_20240102_201328.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_201328.dng'
# Error processing LRM_20240102_201332.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240102_201332.dng'
# Error processing LRM_20240110_115830.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115830.dng'
# Error processing LRM_20240110_115834.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115834.dng'
# Error processing LRM_20240110_115839.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115839.dng'
# Error processing LRM_20240110_115843.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115843.dng'
# Error processing LRM_20240110_115905.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115905.dng'
# Error processing LRM_20240110_115908.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115908.dng'
# Error processing LRM_20240110_115913.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115913.dng'
# Error processing LRM_20240110_115917.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115917.dng'
# Error processing LRM_20240110_115957.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_115957.dng'
# Error processing LRM_20240110_120001.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_120001.dng'
# Error processing LRM_20240110_120005.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_120005.dng'
# Error processing LRM_20240110_120009.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_120009.dng'
# Error processing LRM_20240110_185657.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_185657.dng'
# Error processing LRM_20240110_185706.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_185706.dng'
# Error processing LRM_20240110_185716.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o7\\LRM_20240110_185716.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\o8"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\weqs"
output_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
import cv2

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the target width and height
target_width = 3000
target_height = 4000

# Loop through the list of files and resize them
for filename in files:
    try:
        # Open the image using OpenCV
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)
        
        # Check if height is greater than width
        height, width, _ = image.shape
        if height > width:
            # Do nothing if height is greater than width
            continue
        
        # Rotate the image to the right
        rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
        
        # Resize the rotated image using cubic interpolation for better quality
        resized_image = cv2.resize(rotated_image, (target_width, target_height), interpolation=cv2.INTER_CUBIC)
        
        # Save the resized image
        cv2.imwrite(image_path, resized_image)
    except Exception as e:
        print(f"Error processing {filename}: {e}")

# %%
import os
import random
import string

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Shuffle the list of files randomly
random.shuffle(files)

# Define characters to use for generating random filenames
characters = string.ascii_lowercase + string.digits

# Loop through the shuffled list of files and rename them randomly
for i, filename in enumerate(files):
    # Generate a random filename
    random_filename = ''.join(random.choices(characters, k=10)) + os.path.splitext(filename)[1]
    
    # Construct the new file path with the random filename
    new_filepath = os.path.join(input_folder, random_filename)
    
    # Rename the file
    os.rename(os.path.join(input_folder, filename), new_filepath)

# %%
import os

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(Grass_carp)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the prefix for renaming
prefix = "GC"

# Loop through the list of files and rename them sequentially
for i, filename in enumerate(files, start=1):
    try:
        # Generate the new filename
        new_filename = f"{prefix}{i:03}.jpg"
        
        # Construct the new file path
        old_filepath = os.path.join(input_folder, filename)
        new_filepath = os.path.join(input_folder, new_filename)
        
        # Rename the file
        os.rename(old_filepath, new_filepath)
    except Exception as e:
        print(f"Error renaming {filename}: {e}")

# %%
import os
import cv2

# Define input folder
input_folder = "E:\\Work\\Base data\\cropped\\Grass Carp\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the target width and height
target_width = 3000
target_height = 4000

# Loop through the list of files and resize them
for filename in files:
    try:
        # Open the image using OpenCV
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)
        
        # Resize the image to the target dimensions
        resized_image = cv2.resize(image, (target_width, target_height))
        
        # Save the resized image
        cv2.imwrite(image_path, resized_image)
    except Exception as e:
        print(f"Error processing {filename}: {e}")
