# %%
from PIL import ImageFile

ImageFile.MAX_IMAGE_PIXELS = 99908000000  # Adjust limit as needed (in pixels)

import warnings
from cryptography.utils import CryptographyDeprecationWarning
with warnings.catch_warnings():
    warnings.filterwarnings('ignore', category=CryptographyDeprecationWarning)
    import paramiko

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o1"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing 20231201_162835_1.dng: cannot write mode RGBA as JPEG
# C:\Users\paulp\anaconda3\envs\rmvbg\lib\site-packages\PIL\Image.py:3218: DecompressionBombWarning: Image size (108000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o2"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o3"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o4"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240102_193238.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240102_193238.dng'
# Error processing LRM_20240102_193333.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240102_193333.dng'
# Error processing LRM_20240102_193337.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240102_193337.dng'
# Error processing LRM_20240102_193417.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240102_193417.dng'
# Error processing LRM_20240102_193422.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240102_193422.dng'
# Error processing LRM_20240110_113553.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_113553.dng'
# Error processing LRM_20240110_113555.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_113555.dng'
# Error processing LRM_20240110_113755.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_113755.dng'
# Error processing LRM_20240110_113800.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_113800.dng'
# Error processing LRM_20240110_113804.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_113804.dng'
# Error processing LRM_20240110_113841.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_113841.dng'
# Error processing LRM_20240110_113845.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_113845.dng'
# Error processing LRM_20240110_114118.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_114118.dng'
# Error processing LRM_20240110_114122.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_114122.dng'
# Error processing LRM_20240110_114225.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_114225.dng'
# Error processing LRM_20240110_114308.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_114308.dng'
# Error processing LRM_20240110_114312.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_114312.dng'
# Error processing LRM_20240110_114317.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_114317.dng'
# Error processing LRM_20240110_114321.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_114321.dng'
# Error processing LRM_20240110_115428.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115428.dng'
# Error processing LRM_20240110_115430.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115430.dng'
# Error processing LRM_20240110_115604.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115604.dng'
# Error processing LRM_20240110_115609.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115609.dng'
# Error processing LRM_20240110_115625.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115625.dng'
# Error processing LRM_20240110_115628.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115628.dng'
# Error processing LRM_20240110_115634.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115634.dng'
# Error processing LRM_20240110_115638.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115638.dng'
# Error processing LRM_20240110_115652.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240110_115652.dng'
# Error processing LRM_20240114_175600.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240114_175600.dng'
# Error processing LRM_20240114_175603.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240114_175603.dng'
# Error processing LRM_20240114_175606.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240114_175606.dng'
# Error processing LRM_20240114_175630.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240114_175630.dng'
# Error processing LRM_20240114_175649.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240114_175649.dng'
# Error processing LRM_20240114_175651.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240114_175651.dng'
# Error processing LRM_20240114_175655.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o4\\LRM_20240114_175655.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o5"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240110_113600.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_113600.dng'
# Error processing LRM_20240110_113603.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_113603.dng'
# Error processing LRM_20240110_113703.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_113703.dng'
# Error processing LRM_20240110_113709.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_113709.dng'
# Error processing LRM_20240110_113713.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_113713.dng'
# Error processing LRM_20240110_113717.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_113717.dng'
# Error processing LRM_20240110_113752.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_113752.dng'
# Error processing LRM_20240110_115435.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_115435.dng'
# Error processing LRM_20240110_115438.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_115438.dng'
# Error processing LRM_20240110_115502.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_115502.dng'
# Error processing LRM_20240110_115505.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_115505.dng'
# Error processing LRM_20240110_115539.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_115539.dng'
# Error processing LRM_20240110_115544.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_115544.dng'
# Error processing LRM_20240110_115556.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240110_115556.dng'
# Error processing LRM_20240114_175658.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240114_175658.dng'
# Error processing LRM_20240114_175702.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240114_175702.dng'
# Error processing LRM_20240114_175706.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240114_175706.dng'
# Error processing LRM_20240114_175710.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240114_175710.dng'
# Error processing LRM_20240114_175715.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o5\\LRM_20240114_175715.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o6"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240102_193211.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240102_193211.dng'
# Error processing LRM_20240110_114140.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_114140.dng'
# Error processing LRM_20240110_114143.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_114143.dng'
# Error processing LRM_20240110_114149.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_114149.dng'
# Error processing LRM_20240110_114154.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_114154.dng'
# Error processing LRM_20240110_114212.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_114212.dng'
# Error processing LRM_20240110_114215.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_114215.dng'
# Error processing LRM_20240110_114220.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_114220.dng'
# Error processing LRM_20240110_115733.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_115733.dng'
# Error processing LRM_20240110_115739.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_115739.dng'
# Error processing LRM_20240110_115742.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_115742.dng'
# Error processing LRM_20240110_115757.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_115757.dng'
# Error processing LRM_20240110_115802.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_115802.dng'
# Error processing LRM_20240110_115807.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_115807.dng'
# Error processing LRM_20240110_115811.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o6\\LRM_20240110_115811.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o7"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue
# Out:
# Error processing LRM_20240102_193057.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240102_193057.dng'
# Error processing LRM_20240102_193115.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240102_193115.dng'
# Error processing LRM_20240102_193205.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240102_193205.dng'
# Error processing LRM_20240110_113617.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_113617.dng'
# Error processing LRM_20240110_113623.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_113623.dng'
# Error processing LRM_20240110_113629.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_113629.dng'
# Error processing LRM_20240110_113633.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_113633.dng'
# Error processing LRM_20240110_113850.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_113850.dng'
# Error processing LRM_20240110_113853.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_113853.dng'
# Error processing LRM_20240110_114110.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_114110.dng'
# Error processing LRM_20240110_114113.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_114113.dng'
# Error processing LRM_20240110_114240.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_114240.dng'
# Error processing LRM_20240110_114243.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_114243.dng'
# Error processing LRM_20240110_114248.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_114248.dng'
# Error processing LRM_20240110_114251.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_114251.dng'
# Error processing LRM_20240110_115511.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115511.dng'
# Error processing LRM_20240110_115516.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115516.dng'
# Error processing LRM_20240110_115532.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115532.dng'
# Error processing LRM_20240110_115535.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115535.dng'
# Error processing LRM_20240110_115704.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115704.dng'
# Error processing LRM_20240110_115709.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115709.dng'
# Error processing LRM_20240110_115714.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115714.dng'
# Error processing LRM_20240110_115730.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240110_115730.dng'
# Error processing LRM_20240114_175608.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240114_175608.dng'
# Error processing LRM_20240114_175620.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240114_175620.dng'
# Error processing LRM_20240114_175623.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240114_175623.dng'
# Error processing LRM_20240114_175627.dng: cannot identify image file 'E:\\Work\\Base data\\All Mach\\(mrigle)\\o7\\LRM_20240114_175627.dng'

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\o8"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
from rembg import remove
from PIL import Image
import shutil

# Define input and output folders
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\weqs"
output_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"
error_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\errors"

# Loop through all the files in the input folder
for filename in os.listdir(input_folder):
    try:
        # Check if the file is an image file
        if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.dng') or filename.endswith('.jpeg') or filename.endswith('.JPG'):
            # Define input and output file paths
            input_path = os.path.join(input_folder, filename)
            
            # Check if the file is in '.dng' format and convert it to '.jpg'
            if filename.endswith('.dng'):
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.jpg')
                # Convert '.dng' to '.jpg' using PIL
                with Image.open(input_path) as img:
                    img.convert("RGBA").save(output_path)
            else:
                output_path = os.path.join(output_folder, filename.split('.')[0] + '.png')

            # Load the input image
            input_image = Image.open(input_path)

            # Remove the background using rembg
            output_image = remove(input_image)

            # Create a blank white image with the same size as the output image
            white_background = Image.new("RGB", output_image.size, (255, 255, 255))

            # Composite the output image (foreground) onto the white background
            final_image = Image.alpha_composite(white_background.convert("RGBA"), output_image)

            # Convert RGBA to RGB mode
            final_image = final_image.convert('RGB')

            # Save the output image as a JPG file
            final_image.save(output_path[:-4] + '.JPG')
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        # Move the error-causing file to the error folder
        error_path = os.path.join(error_folder, filename)
        shutil.move(input_path, error_path)
        continue

# %%
import os
import cv2

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the target width and height
target_width = 3000
target_height = 4000

# Loop through the list of files and resize them
for filename in files:
    try:
        # Open the image using OpenCV
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)
        
        # Check if height is greater than width
        height, width, _ = image.shape
        if height > width:
            # Do nothing if height is greater than width
            continue
        
        # Rotate the image to the right
        rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
        
        # Resize the rotated image using cubic interpolation for better quality
        resized_image = cv2.resize(rotated_image, (target_width, target_height), interpolation=cv2.INTER_CUBIC)
        
        # Save the resized image
        cv2.imwrite(image_path, resized_image)
    except Exception as e:
        print(f"Error processing {filename}: {e}")

# %%
import os
import random
import string

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Shuffle the list of files randomly
random.shuffle(files)

# Define characters to use for generating random filenames
characters = string.ascii_lowercase + string.digits

# Loop through the shuffled list of files and rename them randomly
for i, filename in enumerate(files):
    # Generate a random filename
    random_filename = ''.join(random.choices(characters, k=10)) + os.path.splitext(filename)[1]
    
    # Construct the new file path with the random filename
    new_filepath = os.path.join(input_folder, random_filename)
    
    # Rename the file
    os.rename(os.path.join(input_folder, filename), new_filepath)

# %%
import os

# Define input folder
input_folder = "E:\\Work\\Base data\\All Mach\\(mrigle)\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the prefix for renaming
prefix = "M"

# Loop through the list of files and rename them sequentially
for i, filename in enumerate(files, start=1):
    try:
        # Generate the new filename
        new_filename = f"{prefix}{i:03}.jpg"
        
        # Construct the new file path
        old_filepath = os.path.join(input_folder, filename)
        new_filepath = os.path.join(input_folder, new_filename)
        
        # Rename the file
        os.rename(old_filepath, new_filepath)
    except Exception as e:
        print(f"Error renaming {filename}: {e}")

# %%
import os
import cv2

# Define input folder
input_folder = "E:\\Work\\Base data\\cropped\\Mrigle\\output"

# Get the list of files in the input folder
files = os.listdir(input_folder)

# Define the target width and height
target_width = 3000
target_height = 4000

# Loop through the list of files and resize them
for filename in files:
    try:
        # Open the image using OpenCV
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path)
        
        # Resize the image to the target dimensions
        resized_image = cv2.resize(image, (target_width, target_height))
        
        # Save the resized image
        cv2.imwrite(image_path, resized_image)
    except Exception as e:
        print(f"Error processing {filename}: {e}")
